# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !CUDA_VISIBLE_DEVICES=0 python /content/drive/MyDrive/AI홀로서기/1기/AI홀로서기_1기_수강생_공유/라이브코드/4주차/train.py --lr 0.1
# Out:
# ...
# 100% 170498071/170498071 [00:13<00:00, 12790018.65it/s]
# Extracting ./cifar/cifar-10-python.tar.gz to ./cifar
# Files already downloaded and verified
# 2.3256263732910156
# accuracy :  0.1002
# new best model saved! acc : 10.02
# 3.336989164352417
# accuracy :  0.1004
# new best model saved! acc : 10.04
# 2.8100380897521973
# accuracy :  0.1
# 2.711834669113159
# accuracy :  0.1
# 2.3923707008361816
# accuracy :  0.1
# 2.3803956508636475
# accuracy :  0.1
# 2.414321184158325
# accuracy :  0.1
# 2.297142267227173
# accuracy :  0.1
# 2.3221395015716553
# accuracy :  0.1
# 2.3147013187408447
# accuracy :  0.1
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/AI홀로서기/1기/AI홀로서기_1기_수강생_공유/라이브코드/4주차/train.py", line 60, in <module>
#     main()
#   File "/content/drive/MyDrive/AI홀로서기/1기/AI홀로서기_1기_수강생_공유/라이브코드/4주차/train.py", line 38, in main
#     for idx, (image, target) in enumerate(train_loader):
# ...
