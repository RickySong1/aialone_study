# %%
# !python LeNet5.py
# Out:
# 2.312342405319214
# accuracy :  0.1517
# 0.14913120865821838
# accuracy :  0.9582
# 0.1468406319618225
# accuracy :  0.9695
# 0.18781667947769165
# accuracy :  0.9736
# 0.017191968858242035
# accuracy :  0.9801
# 0.18079210817813873
# accuracy :  0.9788
# 0.04838552325963974
# accuracy :  0.9814
# 0.013086548075079918
# accuracy :  0.9807
# 0.039797019213438034
# accuracy :  0.981
# 0.03753636032342911
# accuracy :  0.9858
# 0.04498177394270897
# accuracy :  0.9835
# 0.009197383187711239
# accuracy :  0.9845
# 0.043012555688619614
# accuracy :  0.9848
# 0.0381280742585659
# accuracy :  0.9856
# 0.007721962407231331
# accuracy :  0.9813
# 0.04521150141954422
# accuracy :  0.985
# 0.13640187680721283
# accuracy :  0.9843
# 0.061281219124794006
# accuracy :  0.9811

# %%
import os
os.listdir()
# Out:
# ['.config', '[2주차] LeNet5.py', 'sample_data']
